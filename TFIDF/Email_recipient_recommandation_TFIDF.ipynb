# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = 'data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
import TFIDF_mod
from TFIDF_mod import TFIDF

# transform each mail body into tfidf vector
# /!\ function can take 1-2 min to execute
TFIDF = TFIDF()
X_TFIDF = TFIDF.fit_transform(X_df) # resulting shape : (43613, 275988)

# %%
from sklearn.model_selection import ShuffleSplit
import predictor
from predictor import Predictor_1

# splitting data for cross validation
skf = ShuffleSplit(n_splits=1, test_size=0.2)
print('%10s | %40s | %10s | %10s' %('sender_nb', 'sender', 'accuracy','accuracy freq'))
print('%10s + %40s + %10s + %13s' %(10*'-', 40*'-', 10*'-', 13*'-'))

for train_is, test_is in skf.split(y_df):
    
    X_tfidf_train = X_TFIDF[train_is].copy()
    y_train = y_df.recipients.loc[train_is].copy()
    X_tfidf_test = X_TFIDF[test_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    pdt_freq = {}
    accuracy = {}
    accuracy_freq = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)
    y_pred_freq = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_1(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books)
        pdt_freq[sender] = Predictor_1(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books, N=0)
        y_pred[sender_test_is] = pdt[sender].predict_1(X_tfidf_test[sender_test_is])
        y_pred_freq[sender_test_is] = pdt_freq[sender].predict_1(X_tfidf_test[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is])
        accuracy_freq[sender] = mapk(y_test[sender_test_is], y_pred_freq[sender_test_is])
        
        accuracy_TOT += accuracy[sender]
        print('%10s | %13s' %(round(accuracy[sender],2),round(accuracy_freq[sender],2)))

    print('%30s'%(90*'-'))
    print('error TOT = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |   accuracy | accuracy freq
# ---------- + ---------------------------------------- + ---------- + -------------
#          0 |        enron_update@concureworkplace.com |       0.13 |           0.2
#          1 |               larry.f.campbell@enron.com |       0.09 |          0.13
#          2 |                sara.shackleton@enron.com |       0.09 |          0.13
#          3 |                 mark.greenberg@enron.com |        0.3 |          0.55
#          4 |                    amr.ibrahim@enron.com |       0.43 |          0.64
#          5 |                       kim.ward@enron.com |       0.13 |          0.21
#          6 |                 phillip.m.love@enron.com |       0.08 |          0.13
#          7 |                    susan.scott@enron.com |       0.06 |          0.09
#          8 |                      eric.bass@enron.com |       0.14 |           0.2
#          9 |                  chris.dorland@enron.com |       0.11 |          0.18
#         10 |                  michelle.cash@enron.com |       0.14 |          0.26
#         11 |                 mark.mcconnell@enron.com |       0.23 |          0.44
#         12 |                phillip.platter@enron.com |       0.17 |          0.29
#         13 |                     lynn.blair@enron.com |        0.2 |          0.29
#         14 |                     sally.beck@enron.com |        0.1 |          0.16
#         15 |                 alan.aronowitz@enron.com |       0.24 |           0.4
#         16 |                      m..forney@enron.com |       0.16 |          0.23
#         17 |                   paul.y barbo@enron.com |        0.1 |          0.15
#         18 |                james.d.steffes@enron.com |       0.18 |          0.27
#         19 |                      mary.cook@enron.com |       0.25 |          0.38
#         20 |               hunter.s.shively@enron.com |       0.14 |          0.25
#         21 |                 jonathan.mckay@enron.com |       0.15 |          0.24
#         22 |                     scott.neal@enron.com |       0.13 |          0.22
#         23 |                 ginger.dernehl@enron.com |        0.5 |          0.72
#         24 |                       jbennett@gmssr.com |       0.41 |          0.61
#         25 |                tori.kuykendall@enron.com |       0.07 |          0.12
#         26 |                    karen.denne@enron.com |       0.38 |          0.58
#         27 |                     tim.belden@enron.com |       0.18 |          0.28
#         28 |                  chris.germany@enron.com |       0.08 |          0.12
#         29 |                  sheila.glover@enron.com |       0.31 |          0.55
#         30 |                    alan.comnes@enron.com |       0.36 |          0.56
#         31 |                 kevin.m.presto@enron.com |       0.14 |          0.24
#         32 |                  david.forster@enron.com |       0.29 |          0.53
#         33 |                    andrea.ring@enron.com |       0.22 |          0.37
#         34 |                    marie.heard@enron.com |       0.12 |           0.2
#         35 |                  james.derrick@enron.com |       0.25 |          0.44
#         36 |                    britt.davis@enron.com |       0.29 |          0.45
#         37 |                  lorna.brennan@enron.com |       0.58 |          0.82
#         38 |                 keegan.farrell@enron.com |       0.53 |          0.75
#         39 |                  john.lavorato@enron.com |        0.1 |          0.16
#         40 |                 janel.guerrero@enron.com |       0.43 |          0.62
#         41 |                 stacey.w.white@enron.com |       0.38 |          0.74
#         42 |                russell.diamond@enron.com |       0.23 |          0.35
#         43 |                   mike.grigsby@enron.com |       0.25 |          0.36
#         44 |               errol.mclaughlin@enron.com |       0.15 |          0.22
#         45 |                  brian.redmond@enron.com |       0.29 |           0.5
#         46 |                       rick.buy@enron.com |       0.11 |          0.19
#         47 |                  dutch.quigley@enron.com |       0.16 |          0.29
#         48 |                  tanya.rohauer@enron.com |       0.31 |          0.54
#         49 |                harry.kingerski@enron.com |       0.32 |           0.5
#         50 |                    mark.palmer@enron.com |       0.28 |          0.46
#         51 |                 jason.williams@enron.com |       0.19 |          0.33
#         52 |            darrell.schoolcraft@enron.com |       0.24 |          0.43
#         53 |                    c..williams@enron.com |       0.43 |          0.62
#         54 |                     liz.taylor@enron.com |       0.28 |          0.54
#         55 |               christina.valdez@enron.com |       0.46 |           0.9
#         56 |                 stanley.horton@enron.com |       0.08 |          0.15
#         57 |                       c..giron@enron.com |       0.12 |           0.2
#         58 |                     m..schmidt@enron.com |       0.49 |          0.97
#         59 |                  john.zufferli@enron.com |       0.08 |          0.14
#         60 |                grace.rodriguez@enron.com |        0.3 |          0.52
#         61 |                   shona.wilson@enron.com |       0.27 |          0.45
#         62 |             kenneth.thibodeaux@enron.com |       0.64 |           0.9
#         63 |                        vkaminski@aol.com |       0.43 |          0.79
#         64 |                 barry.tycholiz@enron.com |       0.13 |          0.21
#         65 |                  martin.cuilla@enron.com |       0.12 |          0.18
#         66 |                     mark.whitt@enron.com |       0.26 |          0.44
#         67 |                     bob.shults@enron.com |       0.28 |          0.44
#         68 |                richard.shapiro@enron.com |       0.32 |          0.52
#         69 |                stephanie.panus@enron.com |       0.37 |          0.57
#         70 |                    david.portz@enron.com |       0.21 |          0.36
#         71 |                lisa.mellencamp@enron.com |       0.17 |          0.26
#         72 |                  becky.spencer@enron.com |       0.45 |          0.66
#         73 |                     matt.smith@enron.com |       0.09 |          0.14
#         74 |               holden.salisbury@enron.com |        0.1 |          0.15
#         75 |                 heather.dunton@enron.com |       0.35 |          0.61
#         76 |              kathleen.carnahan@enron.com |       0.42 |          0.78
#         77 |                  karen.buckley@enron.com |       0.22 |          0.31
#         78 |                         taylor@enron.com |        0.1 |          0.15
#         79 |                    w..cantrell@enron.com |       0.48 |           0.7
#         80 |                     wsmith@wordsmith.org |        0.5 |           1.0
#         81 |               fletcher.j.sturm@enron.com |       0.06 |          0.09
#         82 |                kimberly.hillis@enron.com |       0.33 |          0.66
#         83 |                     jane.tholt@enron.com |        0.1 |          0.15
#         84 |                      sylvia.hu@enron.com |        0.2 |          0.26
#         85 |                   beth.cherry@enform.com |       0.48 |          0.94
#         86 |                    rahil.jafry@enron.com |       0.38 |          0.69
#         87 |                 cheryl.johnson@enron.com |       0.67 |          0.95
#         88 |                   megan.parker@enron.com |       0.47 |          0.91
#         89 |                     david.port@enron.com |       0.25 |          0.41
#         90 |                christian.yoder@enron.com |       0.31 |          0.51
#         91 |             joannie.williamson@enron.com |       0.37 |          0.52
#         92 |                    mike.carson@enron.com |       0.08 |          0.11
#         93 |                 justin.rostant@enron.com |       0.45 |          0.67
#         94 |                    jason.wolfe@enron.com |       0.15 |          0.28
#         95 |                      jean.mrha@enron.com |       0.39 |          0.69
#         96 |                  jim.schwieger@enron.com |       0.26 |          0.48
#         97 |                  suzanne.adams@enron.com |       0.41 |          0.77
#         98 |                      l..denton@enron.com |       0.64 |          0.91
#         99 |               monika.causholli@enron.com |       0.19 |           0.3
#        100 |               stephanie.miller@enron.com |       0.33 |          0.55
#        101 |                     brad.mckay@enron.com |       0.12 |           0.2
#        102 |                     l..nicolay@enron.com |        0.4 |          0.64
#        103 |                   holly.keiser@enron.com |       0.46 |          0.64
#        104 |                  peter.keohane@enron.com |       0.22 |          0.35
#        105 |                 patrice.l.mims@enron.com |       0.15 |          0.25
#        106 |                    cindy.stark@enron.com |       0.24 |          0.34
#        107 |                    andy.zipper@enron.com |       0.12 |          0.19
#        108 |               michael.tribolet@enron.com |       0.36 |          0.58
#        109 |                 jennifer.thome@enron.com |       0.44 |          0.69
#        110 |                  paul.d.thomas@enron.com |       0.14 |          0.23
#        111 |               marcus.nettelton@enron.com |       0.35 |          0.64
#        112 |                  andrew.edison@enron.com |       0.26 |          0.41
#        113 |               joe.stepenovitch@enron.com |       0.33 |          0.64
#        114 |                   paul.kaufman@enron.com |       0.34 |          0.54
#        115 |                amy.fitzpatrick@enron.com |       0.39 |          0.77
#        116 |                stephanie.sever@enron.com |       0.41 |          0.68
#        117 |                     ben.jacoby@enron.com |       0.28 |          0.45
#        118 |                     mike.maggi@enron.com |       0.38 |          0.67
#        119 |                            alex@pira.com |        0.5 |           1.0
#        120 |    schwabalerts.marketupdates@schwab.com |        0.5 |           1.0
#        121 |          nancy.sellers@robertmondavi.com |       0.63 |          0.95
#        122 |                     greg.piper@enron.com |       0.21 |          0.32
#        123 |               sandra.f.brawner@enron.com |       0.18 |          0.29
#        124 |                julie.armstrong@enron.com |       0.31 |          0.54
# ------------------------------------------------------------------------------------------
# error TOT = 0.27
