# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = '../data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
from proper_name_extractor import *

# %%
#Extracting proper names in X_train
if False:
    X_tmp=add_proper_names(X_df)
    X_tmp.to_csv('data_with_proper_names.tsv', sep='\t',na_values=' ')
X_tmp=pd.read_csv('data_with_proper_names.tsv', sep='\t',na_filter=False,index_col=False)
X_tmp.drop(['Unnamed: 0'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d3cc1a26dc06> in <module>()
#       3     X_tmp=add_proper_names(X_df)
#       4     X_tmp.to_csv('data_with_proper_names.tsv', sep='\t',na_values=' ')
# ----> 5 X_tmp=pd.read_csv('data_with_proper_names.tsv', sep='\t',na_filter=False,index_col=False)
#       6 X_tmp.drop(['Unnamed: 0'],axis=1)
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# FileNotFoundError: File b'data_with_proper_names.tsv' does not exist

# %%
#Name per address creation

surname_link, recipients_link=create_name_dict(X_tmp, y_df)

# %%
def complete_prediction(k, sender, address_books, res_temp, K=10):
    # k the number of recipients to predict
    k_most = [elt[0] for elt in address_books[sender][:K] if elt not in res_temp]
    k_most = k_most[:k]
    if len(k_most) < k: # sender n'a pas assez de contacts
        k_most.extend([0] * (k-len(k_most)))
    return k_most

class Predictor_Names():
    def __init__(self, X, y, sender, address_books):
        self.train = X
        self.predict = y.values
        self.sender = sender
        self.address_books = address_books
        pass

    def pred(self, X):
        res = []#np.empty((X.shape[0],10))
        for x in X.values:
            res_temp=[]
            sender=x[3]
            name_list=extract_names(x[2]) #extract name from body
            score={}
            for r in address_books[sender]:
                rec=r[0]
                score[rec]=0
                for name in name_list.split(','):
                    if name in recipients_link[rec]:
                        score[rec]=score[rec]+1
            score=sorted(score.items(), key=operator.itemgetter(1), reverse = True)
            count=0
            if len(score)>0:
                s=score[count][1]
            else:
                s=0
            while s>0 and count<10:
                res_temp.append(score[count][0])
                count=count+1
                if len(score)>count:
                    s=score[count][1]
                else:
                    s=0
            if len(res_temp) < 10:
                res_temp.extend(complete_prediction(10-len(res_temp),self.sender, self.address_books, res_temp))
            res.append(res_temp)
        return res

# %%
from sklearn.model_selection import ShuffleSplit
import predictor

# splitting data for cross validation
skf = ShuffleSplit(n_splits=2, test_size=0.2)
print('%10s | %40s | %10s' %('sender_nb', 'sender', 'accuracy'))
print('%10s + %40s + %10s' %(10*'-', 40*'-', 10*'-'))
for train_is, test_is in skf.split(y_df):
    
    y_train = y_df.recipients.loc[train_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    accuracy = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_Names(X_train_df[sender_train_is], y_train[sender_train_is], sender, address_books)
        y_pred[sender_test_is] = pdt[sender].pred(X_test_df[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is], k=10)
        accuracy_TOT += accuracy[sender]
        print('%.2f' %(accuracy[sender]))

    print('%30s'%(30*'-'))
    print('error TOT = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |   accuracy
# ---------- + ---------------------------------------- + ----------
#          0 |                   holly.keiser@enron.com | 0.08
#          1 |                  chris.germany@enron.com | 0.23
#          2 |               fletcher.j.sturm@enron.com | 0.17
#          3 |                      m..forney@enron.com | 0.30
#          4 |                 jonathan.mckay@enron.com | 0.29
#          5 |                      eric.bass@enron.com | 0.30
#          6 |                 phillip.m.love@enron.com | 0.25
#          7 |          nancy.sellers@robertmondavi.com | 0.82
#          8 |                amy.fitzpatrick@enron.com | 0.19
#          9 |                james.d.steffes@enron.com | 0.26
#         10 |                     scott.neal@enron.com | 0.38
#         11 |               larry.f.campbell@enron.com | 0.41
#         12 |               sandra.f.brawner@enron.com | 0.54
#         13 |                  becky.spencer@enron.com | 0.40
#         14 |                sara.shackleton@enron.com | 0.26
#         15 |                    c..williams@enron.com | 0.41
#         16 |                richard.shapiro@enron.com | 0.35
#         17 |                harry.kingerski@enron.com | 0.21
#         18 |                 kevin.m.presto@enron.com | 0.25
#         19 |                    susan.scott@enron.com | 0.29
#         20 |                      l..denton@enron.com | 0.84
#         21 |                  michelle.cash@enron.com | 0.47
#         22 |                    marie.heard@enron.com | 0.19
#         23 |                  john.lavorato@enron.com | 0.19
#         24 |                     lynn.blair@enron.com | 0.28
#         25 |            darrell.schoolcraft@enron.com | 0.30
#         26 |                     sally.beck@enron.com | 0.34
#         27 |                stephanie.panus@enron.com | 0.27
#         28 |               michael.tribolet@enron.com | 0.44
#         29 |        enron_update@concureworkplace.com | 0.39
#         30 |                 stacey.w.white@enron.com | 0.19
#         31 |                     liz.taylor@enron.com | 0.39
#         32 |                     jane.tholt@enron.com | 0.35
#         33 |                       rick.buy@enron.com | 0.15
#         34 |                    andrea.ring@enron.com | 0.47
#         35 |                  sheila.glover@enron.com | 0.55
#         36 |                    cindy.stark@enron.com | 0.58
#         37 |                     tim.belden@enron.com | 0.32
#         38 |                    karen.denne@enron.com | 0.38
#         39 |                  chris.dorland@enron.com | 0.29
#         40 |                   shona.wilson@enron.com | 0.37
#         41 |                 barry.tycholiz@enron.com | 0.21
#         42 |                  peter.keohane@enron.com | 0.31
#         43 |                christian.yoder@enron.com | 0.41
#         44 |                 jennifer.thome@enron.com | 0.23
#         45 |               errol.mclaughlin@enron.com | 0.45
#         46 |                 ginger.dernehl@enron.com | 0.47
#         47 |                 stanley.horton@enron.com | 0.36
#         48 |                         taylor@enron.com | 0.19
#         49 |                    w..cantrell@enron.com | 0.44
#         50 |                 mark.greenberg@enron.com | 0.33
#         51 |                   mike.grigsby@enron.com | 0.21
#         52 |               monika.causholli@enron.com | 0.53
#         53 |                  david.forster@enron.com | 0.30
#         54 |                     m..schmidt@enron.com | 0.98
#         55 |                       c..giron@enron.com | 0.36
#         56 |                  lorna.brennan@enron.com | 0.66
#         57 |                tori.kuykendall@enron.com | 0.23
#         58 |                  karen.buckley@enron.com | 0.18
#         59 |                  james.derrick@enron.com | 0.40
#         60 |                kimberly.hillis@enron.com | 0.57
#         61 |                  brian.redmond@enron.com | 0.43
#         62 |                    andy.zipper@enron.com | 0.22
#         63 |                     wsmith@wordsmith.org | 1.00
#         64 |                russell.diamond@enron.com | 0.37
#         65 |                     matt.smith@enron.com | 0.42
#         66 |                 heather.dunton@enron.com | 0.58
#         67 |                stephanie.sever@enron.com | 0.34
#         68 |                 keegan.farrell@enron.com | 0.17
#         69 |                   paul.y barbo@enron.com | 0.35
#         70 |                     david.port@enron.com | 0.46
#         71 |                   megan.parker@enron.com | 0.93
#         72 |                      mary.cook@enron.com | 0.27
#         73 |              kathleen.carnahan@enron.com | 0.54
#         74 |                  suzanne.adams@enron.com | 0.46
#         75 |                    david.portz@enron.com | 0.51
#         76 |                 mark.mcconnell@enron.com | 0.46
#         77 |                     ben.jacoby@enron.com | 0.30
#         78 |                    rahil.jafry@enron.com | 0.61
#         79 |                       jbennett@gmssr.com | 0.48
#         80 |                     bob.shults@enron.com | 0.34
#         81 |                 cheryl.johnson@enron.com | 0.85
#         82 |               holden.salisbury@enron.com | 0.46
#         83 |                    alan.comnes@enron.com | 0.32
#         84 |                            alex@pira.com | 1.00
#         85 |                     mark.whitt@enron.com | 0.49
#         86 |                phillip.platter@enron.com | 0.45
#         87 |               marcus.nettelton@enron.com | 0.78
#         88 |                  martin.cuilla@enron.com | 0.29
#         89 |                     l..nicolay@enron.com | 0.42
#         90 |               hunter.s.shively@enron.com | 0.25
#         91 |                 justin.rostant@enron.com | 0.48
#         92 |                     brad.mckay@enron.com | 0.80
#         93 |                 alan.aronowitz@enron.com | 0.45
#         94 |                       kim.ward@enron.com | 0.25
#         95 |                grace.rodriguez@enron.com | 0.50
#         96 |                      sylvia.hu@enron.com | 0.43
#         97 |                    amr.ibrahim@enron.com | 0.57
#         98 |                  tanya.rohauer@enron.com | 0.31
#         99 |                  jim.schwieger@enron.com | 0.43
#        100 |                     greg.piper@enron.com | 0.30
#        101 |                     mike.maggi@enron.com | 0.82
#        102 |                    jason.wolfe@enron.com | 0.38
#        103 |                   paul.kaufman@enron.com | 0.32
#        104 |                  john.zufferli@enron.com | 0.37
#        105 |                 jason.williams@enron.com | 0.22
#        106 |                    mike.carson@enron.com | 0.35
#        107 |               joe.stepenovitch@enron.com | 0.74
#        108 |               christina.valdez@enron.com | 0.56
#        109 |             kenneth.thibodeaux@enron.com | 0.76
#        110 |                 patrice.l.mims@enron.com | 0.50
#        111 |                  dutch.quigley@enron.com | 0.43
#        112 |             joannie.williamson@enron.com | 0.46
#        113 |                  paul.d.thomas@enron.com | 0.49
#        114 |                        vkaminski@aol.com | 0.91
#        115 |                 janel.guerrero@enron.com | 0.40
#        116 |                   beth.cherry@enform.com | 0.74
#        117 |                      jean.mrha@enron.com | 0.46
#        118 |                lisa.mellencamp@enron.com | 0.29
#        119 |                    britt.davis@enron.com | 0.64
#        120 |                    mark.palmer@enron.com | 0.40
#        121 |                  andrew.edison@enron.com | 0.33
#        122 |                julie.armstrong@enron.com | 0.46
#        123 |    schwabalerts.marketupdates@schwab.com | 1.00
#        124 |               stephanie.miller@enron.com | 0.31
# ------------------------------
# error TOT = 0.43
#          0 |                       kim.ward@enron.com | 0.24
#          1 |                    susan.scott@enron.com | 0.29
#          2 |                         taylor@enron.com | 0.19
#          3 |                   paul.kaufman@enron.com | 0.37
#          4 |                  tanya.rohauer@enron.com | 0.36
#          5 |                      eric.bass@enron.com | 0.31
#          6 |                       c..giron@enron.com | 0.31
#          7 |                 justin.rostant@enron.com | 0.44
#          8 |                richard.shapiro@enron.com | 0.38
#          9 |                  john.lavorato@enron.com | 0.21
#         10 |                 stanley.horton@enron.com | 0.42
#         11 |                 phillip.m.love@enron.com | 0.29
#         12 |                     lynn.blair@enron.com | 0.29
#         13 |                 stacey.w.white@enron.com | 0.20
#         14 |                  michelle.cash@enron.com | 0.43
#         15 |                     mark.whitt@enron.com | 0.45
#         16 |               joe.stepenovitch@enron.com | 0.70
#         17 |                     sally.beck@enron.com | 0.37
#         18 |               larry.f.campbell@enron.com | 0.47
#         19 |                    david.portz@enron.com | 0.54
#         20 |                sara.shackleton@enron.com | 0.26
#         21 |                      l..denton@enron.com | 0.84
#         22 |                 alan.aronowitz@enron.com | 0.44
#         23 |                 kevin.m.presto@enron.com | 0.21
#         24 |                  chris.germany@enron.com | 0.22
#         25 |                james.d.steffes@enron.com | 0.26
#         26 |                   shona.wilson@enron.com | 0.38
#         27 |                    w..cantrell@enron.com | 0.50
#         28 |                     matt.smith@enron.com | 0.32
#         29 |               errol.mclaughlin@enron.com | 0.43
#         30 |                   mike.grigsby@enron.com | 0.22
#         31 |                 mark.mcconnell@enron.com | 0.48
#         32 |                  john.zufferli@enron.com | 0.30
#         33 |                 janel.guerrero@enron.com | 0.52
#         34 |                      m..forney@enron.com | 0.30
#         35 |               christina.valdez@enron.com | 0.68
#         36 |                 keegan.farrell@enron.com | 0.10
#         37 |                 heather.dunton@enron.com | 0.42
#         38 |                    marie.heard@enron.com | 0.16
#         39 |                  james.derrick@enron.com | 0.44
#         40 |               stephanie.miller@enron.com | 0.30
#         41 |                  sheila.glover@enron.com | 0.47
#         42 |                  martin.cuilla@enron.com | 0.31
#         43 |                  suzanne.adams@enron.com | 0.48
#         44 |                    mark.palmer@enron.com | 0.31
#         45 |                phillip.platter@enron.com | 0.50
#         46 |                       rick.buy@enron.com | 0.17
#         47 |                kimberly.hillis@enron.com | 0.40
#         48 |                            alex@pira.com | 1.00
#         49 |            darrell.schoolcraft@enron.com | 0.33
#         50 |                      mary.cook@enron.com | 0.24
#         51 |                     wsmith@wordsmith.org | 1.00
#         52 |                 ginger.dernehl@enron.com | 0.56
#         53 |                  david.forster@enron.com | 0.30
#         54 |                stephanie.sever@enron.com | 0.33
#         55 |                     scott.neal@enron.com | 0.40
#         56 |                grace.rodriguez@enron.com | 0.49
#         57 |                   megan.parker@enron.com | 0.91
#         58 |                  dutch.quigley@enron.com | 0.35
#         59 |               hunter.s.shively@enron.com | 0.29
#         60 |                 patrice.l.mims@enron.com | 0.50
#         61 |               sandra.f.brawner@enron.com | 0.53
#         62 |                    cindy.stark@enron.com | 0.67
#         63 |             joannie.williamson@enron.com | 0.69
#         64 |               michael.tribolet@enron.com | 0.46
#         65 |                  chris.dorland@enron.com | 0.27
#         66 |                    andy.zipper@enron.com | 0.20
#         67 |                     liz.taylor@enron.com | 0.36
#         68 |                stephanie.panus@enron.com | 0.29
#         69 |                  peter.keohane@enron.com | 0.40
#         70 |                  jim.schwieger@enron.com | 0.54
#         71 |                 barry.tycholiz@enron.com | 0.21
#         72 |                    c..williams@enron.com | 0.29
#         73 |        enron_update@concureworkplace.com | 0.28
#         74 |    schwabalerts.marketupdates@schwab.com | 1.00
#         75 |                 jonathan.mckay@enron.com | 0.25
#         76 |                    rahil.jafry@enron.com | 0.54
#         77 |          nancy.sellers@robertmondavi.com | 0.87
#         78 |                      jean.mrha@enron.com | 0.46
#         79 |                   holly.keiser@enron.com | 0.19
#         80 |                     l..nicolay@enron.com | 0.35
#         81 |                  lorna.brennan@enron.com | 0.72
#         82 |               monika.causholli@enron.com | 0.52
#         83 |                amy.fitzpatrick@enron.com | 0.32
#         84 |                  karen.buckley@enron.com | 0.22
#         85 |              kathleen.carnahan@enron.com | 0.42
#         86 |                russell.diamond@enron.com | 0.33
#         87 |             kenneth.thibodeaux@enron.com | 0.70
#         88 |                     m..schmidt@enron.com | 0.97
#         89 |                    karen.denne@enron.com | 0.41
#         90 |                     bob.shults@enron.com | 0.38
#         91 |                  brian.redmond@enron.com | 0.64
#         92 |                 mark.greenberg@enron.com | 0.37
#         93 |                     greg.piper@enron.com | 0.35
#         94 |                    mike.carson@enron.com | 0.36
#         95 |                     jane.tholt@enron.com | 0.25
#         96 |                   paul.y barbo@enron.com | 0.34
#         97 |                tori.kuykendall@enron.com | 0.24
#         98 |                    alan.comnes@enron.com | 0.34
#         99 |                    amr.ibrahim@enron.com | 0.54
#        100 |                       jbennett@gmssr.com | 0.47
#        101 |                 cheryl.johnson@enron.com | 0.72
#        102 |               marcus.nettelton@enron.com | 0.73
#        103 |                     brad.mckay@enron.com | 0.39
#        104 |                     ben.jacoby@enron.com | 0.30
#        105 |                 jennifer.thome@enron.com | 0.21
#        106 |                  paul.d.thomas@enron.com | 0.53
#        107 |               fletcher.j.sturm@enron.com | 0.18
#        108 |                        vkaminski@aol.com | 0.88
#        109 |               holden.salisbury@enron.com | 0.41
#        110 |                    britt.davis@enron.com | 0.72
#        111 |                     tim.belden@enron.com | 0.25
#        112 |                   beth.cherry@enform.com | 0.72
#        113 |                  andrew.edison@enron.com | 0.46
#        114 |                lisa.mellencamp@enron.com | 0.32
#        115 |                 jason.williams@enron.com | 0.20
#        116 |                harry.kingerski@enron.com | 0.17
#        117 |                    andrea.ring@enron.com | 0.46
#        118 |                    jason.wolfe@enron.com | 0.51
#        119 |                julie.armstrong@enron.com | 0.49
#        120 |                     mike.maggi@enron.com | 0.69
#        121 |                     david.port@enron.com | 0.32
#        122 |                  becky.spencer@enron.com | 0.32
#        123 |                christian.yoder@enron.com | 0.33
#        124 |                      sylvia.hu@enron.com | 0.47
# ------------------------------
# error TOT = 0.42

# %% [markdown]
# <h2>Create submission</h2>

# %%
def create_submission(y_pred,X_test_df):

    predictions_towrite={}
    x_test=X_test_df.values
    for i in range(len(y_pred)):
        recipients=y_pred[i]
        mid=x_test[i][0]
        predictions_towrite[mid]=recipients

    count=0
    with open('./pred_custom.txt', 'w') as my_file:
        my_file.write('mid,recipients' + '\n')
        for ids, preds in predictions_towrite.items():
            count=count+1
            r=str(ids)+","
            for s in preds:
                r=r+" "+str(s)
            r=r+'\n'
            my_file.write(r)

# %%
sender_test = X_sub_df.sender.unique().tolist()
y_pred = np.empty((X_sub_df.shape[0],10),dtype=object)
count=0
pdt = {}

for sender in sender_test:
    # indices corresponding to the sender
    sender_train_is = np.array(X_df.sender == sender)
    sender_test_is = np.array(X_sub_df.sender == sender)
    
    y_train_all = y_df.recipients.copy()
    pdt[sender] = Predictor_Names(X_df[sender_train_is], y_train_all[sender_train_is], sender, address_books)
    y_pred[sender_test_is] = pdt[sender].pred(X_sub_df[sender_test_is])
    
create_submission(y_pred,X_sub_df)
