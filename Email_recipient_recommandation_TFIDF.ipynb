# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = 'data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
from proper_name_extractor import *

# %%
#Extracting proper names in X_train

X_tmp=add_proper_names(X_df)
X_tmp.to_csv('data_with_proper_names.tsv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-93844a1c5239> in <module>()
#       1 #Extracting proper names in X_train
#       2
# ----> 3 X_tmp=add_proper_names(X_df)
#       4 X_tmp.to_csv('data_with_proper_names.tsv', sep='\t')
#
# NameError: name 'add_proper_names' is not defined

# %%
#Name per address creation

surname_link, recipients_link=create_name_dict(X_tmp, y_df)

# %%
from sklearn.model_selection import ShuffleSplit
import predictor

# splitting data for cross validation
skf = ShuffleSplit(n_splits=2, test_size=0.2)
print('%10s | %40s | %10s' %('sender_nb', 'sender', 'accuracy'))
print('%10s + %40s + %10s' %(10*'-', 40*'-', 10*'-'))
for train_is, test_is in skf.split(y_df):
    
    X_tfidf_train = X_TFIDF[train_is].copy()
    y_train = y_df.recipients.loc[train_is].copy()
    X_tfidf_test = X_TFIDF[test_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    accuracy = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_Names(X_train_df[sender_train_is], y_train[sender_train_is], sender, address_books)
        y_pred[sender_test_is] = pdt[sender].pred(X_test_df[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is], k=10)
        accuracy_TOT += accuracy[sender]
        print('%.2f' %(accuracy[sender]))

    print('%30s'%(30*'-'))
    print('error TOT = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |   accuracy
# ---------- + ---------------------------------------- + ----------
#          0 |                    david.portz@enron.com | 0.39
#          1 |                russell.diamond@enron.com | 0.23
#          2 |                      eric.bass@enron.com | 0.30
#          3 |                   paul.y barbo@enron.com | 0.38
#          4 |                    marie.heard@enron.com | 0.15
#          5 |                     sally.beck@enron.com | 0.36
#          6 |                  suzanne.adams@enron.com | 0.57
#          7 |                     jane.tholt@enron.com | 0.28
#          8 |                richard.shapiro@enron.com | 0.27
#          9 |                 phillip.m.love@enron.com | 0.24
#         10 |                grace.rodriguez@enron.com | 0.45
#         11 |                  jim.schwieger@enron.com | 0.42
#         12 |                  michelle.cash@enron.com | 0.46
#         13 |                    susan.scott@enron.com | 0.27
#         14 |                sara.shackleton@enron.com | 0.24
#         15 |                   mike.grigsby@enron.com | 0.21
#         16 |                   holly.keiser@enron.com | 0.23
#         17 |                  james.derrick@enron.com | 0.40
#         18 |               errol.mclaughlin@enron.com | 0.27
#         19 |                    rahil.jafry@enron.com | 0.55
#         20 |                  david.forster@enron.com | 0.24
#         21 |                      jean.mrha@enron.com | 0.50
#         22 |                     mark.whitt@enron.com | 0.38
#         23 |                  brian.redmond@enron.com | 0.28
#         24 |               monika.causholli@enron.com | 0.60
#         25 |          nancy.sellers@robertmondavi.com | 0.83
#         26 |                        vkaminski@aol.com | 0.98
#         27 |                 jennifer.thome@enron.com | 0.32
#         28 |                james.d.steffes@enron.com | 0.18
#         29 |                     ben.jacoby@enron.com | 0.29
#         30 |                 ginger.dernehl@enron.com | 0.37
#         31 |                     bob.shults@enron.com | 0.38
#         32 |                  john.lavorato@enron.com | 0.17
#         33 |                  chris.germany@enron.com | 0.24
#         34 |                    cindy.stark@enron.com | 0.55
#         35 |             kenneth.thibodeaux@enron.com | 0.76
#         36 |               larry.f.campbell@enron.com | 0.41
#         37 |                    andrea.ring@enron.com | 0.50
#         38 |                tori.kuykendall@enron.com | 0.30
#         39 |            darrell.schoolcraft@enron.com | 0.34
#         40 |                         taylor@enron.com | 0.24
#         41 |                    alan.comnes@enron.com | 0.28
#         42 |               michael.tribolet@enron.com | 0.34
#         43 |                  martin.cuilla@enron.com | 0.35
#         44 |                       rick.buy@enron.com | 0.17
#         45 |                 stacey.w.white@enron.com | 0.23
#         46 |                     m..schmidt@enron.com | 0.95
#         47 |                  karen.buckley@enron.com | 0.20
#         48 |                 stanley.horton@enron.com | 0.37
#         49 |                 cheryl.johnson@enron.com | 0.81
#         50 |                    mike.carson@enron.com | 0.33
#         51 |                     liz.taylor@enron.com | 0.38
#         52 |                  chris.dorland@enron.com | 0.26
#         53 |                      m..forney@enron.com | 0.31
#         54 |                       jbennett@gmssr.com | 0.41
#         55 |               hunter.s.shively@enron.com | 0.46
#         56 |        enron_update@concureworkplace.com | 0.16
#         57 |                     scott.neal@enron.com | 0.41
#         58 |                     lynn.blair@enron.com | 0.32
#         59 |                stephanie.sever@enron.com | 0.39
#         60 |                    amr.ibrahim@enron.com | 0.35
#         61 |                     matt.smith@enron.com | 0.27
#         62 |                 keegan.farrell@enron.com | 0.15
#         63 |                    andrea.ring@enron.com | 0.50
#         64 |                     brad.mckay@enron.com | 0.48
#         65 |            darrell.schoolcraft@enron.com | 0.34
#         66 |                   mike.grigsby@enron.com | 0.21
#         67 |                       c..giron@enron.com | 0.34
#         68 |                 keegan.farrell@enron.com | 0.10
#         69 |               marcus.nettelton@enron.com | 0.42
#         70 |                 jonathan.mckay@enron.com | 0.35
#         71 |                    mark.palmer@enron.com | 0.36
#         72 |               monika.causholli@enron.com | 0.65
#         73 |             kenneth.thibodeaux@enron.com | 0.79
#         74 |                  john.lavorato@enron.com | 0.17
#         75 |               larry.f.campbell@enron.com | 0.43
#         76 |                  lorna.brennan@enron.com | 0.59
#         77 |                      jean.mrha@enron.com | 0.45
#         78 |                  andrew.edison@enron.com | 0.51
#         79 |                  david.forster@enron.com | 0.20
#         80 |              kathleen.carnahan@enron.com | 0.73
#         81 |                 cheryl.johnson@enron.com | 0.82
#         82 |                 stacey.w.white@enron.com | 0.20
#         83 |               michael.tribolet@enron.com | 0.36
#         84 |                 heather.dunton@enron.com | 0.54
#         85 |                julie.armstrong@enron.com | 0.48
#         86 |                 patrice.l.mims@enron.com | 0.46
#         87 |                         taylor@enron.com | 0.18
#         88 |                    cindy.stark@enron.com | 0.53
#         89 |                     david.port@enron.com | 0.40
#         90 |                    c..williams@enron.com | 0.36
#         91 |                stephanie.sever@enron.com | 0.42
#         92 |                russell.diamond@enron.com | 0.28
#         93 |                 barry.tycholiz@enron.com | 0.16
#         94 |                     greg.piper@enron.com | 0.33
#         95 |                      sylvia.hu@enron.com | 0.49
#         96 |               fletcher.j.sturm@enron.com | 0.22
#         97 |                      m..forney@enron.com | 0.31
#         98 |                  tanya.rohauer@enron.com | 0.35
#         99 |                   beth.cherry@enform.com | 0.67
#        100 |                 mark.mcconnell@enron.com | 0.55
#        101 |    schwabalerts.marketupdates@schwab.com | 1.00
#        102 |                   holly.keiser@enron.com | 0.11
#        103 |                  martin.cuilla@enron.com | 0.35
#        104 |                     l..nicolay@enron.com | 0.32
#        105 |                kimberly.hillis@enron.com | 0.58
#        106 |                    britt.davis@enron.com | 0.70
#        107 |               joe.stepenovitch@enron.com | 0.66
#        108 |                     bob.shults@enron.com | 0.33
#        109 |                 alan.aronowitz@enron.com | 0.48
#        110 |                   shona.wilson@enron.com | 0.42
#        111 |                      l..denton@enron.com | 0.94
#        112 |                   paul.y barbo@enron.com | 0.57
#        113 |                grace.rodriguez@enron.com | 0.41
#        114 |                   paul.kaufman@enron.com | 0.37
#        115 |                    amr.ibrahim@enron.com | 0.22
#        116 |                phillip.platter@enron.com | 0.31
#        117 |                  becky.spencer@enron.com | 0.42
#        118 |               stephanie.miller@enron.com | 0.20
#        119 |                    david.portz@enron.com | 0.42
#        120 |                     mike.maggi@enron.com | 0.61
#        121 |                    w..cantrell@enron.com | 0.67
#        122 |                        vkaminski@aol.com | 0.96
#        123 |                    jason.wolfe@enron.com | 0.19
#        124 |                 justin.rostant@enron.com | 0.63
# ------------------------------
# error TOT = 0.41
