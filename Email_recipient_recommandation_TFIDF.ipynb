# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = 'data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
import TFIDF_mod
from TFIDF_mod import TFIDF
nltk.download("stopwords")
nltk.download("punkt")

# transform each mail body into tfidf vector
# /!\ function can take 1-2 min to execute
TFIDF = TFIDF()
X_TFIDF = TFIDF.fit_transform(X_df) # resulting shape : (43613, 275988)

# %%
from sklearn.model_selection import ShuffleSplit
import predictor
from predictor import Predictor_1

# splitting data for cross validation
skf = ShuffleSplit(n_splits=2, test_size=0.2)
print('%10s | %40s | %10s' %('sender_nb', 'sender', 'accuracy'))
print('%10s + %40s + %10s' %(10*'-', 40*'-', 10*'-'))
for train_is, test_is in skf.split(y_df):
    
    X_tfidf_train = X_TFIDF[train_is].copy()
    y_train = y_df.recipients.loc[train_is].copy()
    X_tfidf_test = X_TFIDF[test_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    accuracy = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_1(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books)
        y_pred[sender_test_is] = pdt[sender].predict_1(X_tfidf_test[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is], k=10)
        accuracy_TOT += accuracy[sender]
        print('%.2f' %(accuracy[sender]))

    print('%30s'%(30*'-'))
    print('error TOT = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |   accuracy
# ---------- + ---------------------------------------- + ----------
#          0 |               monika.causholli@enron.com | 0.18
#          1 |                         taylor@enron.com | 0.11
#          2 |                  chris.germany@enron.com | 0.07
#          3 |                 justin.rostant@enron.com | 0.49
#          4 |                 mark.greenberg@enron.com | 0.32
#          5 |                 kevin.m.presto@enron.com | 0.10
#          6 |                  michelle.cash@enron.com | 0.12
#          7 |                     lynn.blair@enron.com | 0.17
#          8 |                sara.shackleton@enron.com | 0.08
#          9 |                    andy.zipper@enron.com | 0.08
#         10 |                  david.forster@enron.com | 0.29
#         11 |                   megan.parker@enron.com | 0.44
#         12 |                  becky.spencer@enron.com | 0.50
#         13 |                   paul.y barbo@enron.com | 0.18
#         14 |                       kim.ward@enron.com | 0.15
#         15 |                   mike.grigsby@enron.com | 0.21
#         16 |                richard.shapiro@enron.com | 0.30
#         17 |                     brad.mckay@enron.com | 0.13
#         18 |                    susan.scott@enron.com | 0.07
#         19 |                    mark.palmer@enron.com | 0.30
#         20 |                 stanley.horton@enron.com | 0.11
#         21 |                     wsmith@wordsmith.org | 0.50
#         22 |               holden.salisbury@enron.com | 0.11
#         23 |                  john.lavorato@enron.com | 0.11
#         24 |                       c..giron@enron.com | 0.14
#         25 |                     mark.whitt@enron.com | 0.20
#         26 |                james.d.steffes@enron.com | 0.14
#         27 |                     scott.neal@enron.com | 0.10
#         28 |                    karen.denne@enron.com | 0.36
#         29 |                 ginger.dernehl@enron.com | 0.55
#         30 |        enron_update@concureworkplace.com | 0.16
#         31 |               marcus.nettelton@enron.com | 0.35
#         32 |                      mary.cook@enron.com | 0.22
#         33 |                            alex@pira.com | 0.50
#         34 |                    marie.heard@enron.com | 0.11
#         35 |                  james.derrick@enron.com | 0.26
#         36 |                tori.kuykendall@enron.com | 0.06
#         37 |                stephanie.panus@enron.com | 0.40
#         38 |                 mark.mcconnell@enron.com | 0.18
#         39 |                 stacey.w.white@enron.com | 0.37
#         40 |                  chris.dorland@enron.com | 0.14
#         41 |                russell.diamond@enron.com | 0.22
#         42 |               larry.f.campbell@enron.com | 0.09
#         43 |                      eric.bass@enron.com | 0.13
#         44 |                       rick.buy@enron.com | 0.11
#         45 |                     sally.beck@enron.com | 0.10
#         46 |                 phillip.m.love@enron.com | 0.08
#         47 |                   beth.cherry@enform.com | 0.45
#         48 |                    andrea.ring@enron.com | 0.27
#         49 |                  suzanne.adams@enron.com | 0.43
#         50 |                    cindy.stark@enron.com | 0.29
#         51 |                    c..williams@enron.com | 0.38
#         52 |                    rahil.jafry@enron.com | 0.33
#         53 |                     bob.shults@enron.com | 0.29
#         54 |                     m..schmidt@enron.com | 0.50
#         55 |                stephanie.sever@enron.com | 0.33
#         56 |                 jonathan.mckay@enron.com | 0.12
#         57 |                      m..forney@enron.com | 0.12
#         58 |                    britt.davis@enron.com | 0.27
#         59 |                  martin.cuilla@enron.com | 0.14
#         60 |                    mike.carson@enron.com | 0.14
#         61 |               errol.mclaughlin@enron.com | 0.15
#         62 |                     matt.smith@enron.com | 0.10
#         63 |                 alan.aronowitz@enron.com | 0.18
#         64 |                      sylvia.hu@enron.com | 0.23
#         65 |                phillip.platter@enron.com | 0.08
#         66 |                      jean.mrha@enron.com | 0.36
#         67 |                christian.yoder@enron.com | 0.29
#         68 |                     jane.tholt@enron.com | 0.07
#         69 |                 barry.tycholiz@enron.com | 0.15
#         70 |                     l..nicolay@enron.com | 0.40
#         71 |                 janel.guerrero@enron.com | 0.39
#         72 |                    jason.wolfe@enron.com | 0.16
#         73 |                 jennifer.thome@enron.com | 0.35
#         74 |                  jim.schwieger@enron.com | 0.19
#         75 |             kenneth.thibodeaux@enron.com | 0.62
#         76 |                   holly.keiser@enron.com | 0.51
#         77 |                harry.kingerski@enron.com | 0.33
#         78 |                  peter.keohane@enron.com | 0.22
#         79 |               sandra.f.brawner@enron.com | 0.21
#         80 |               christina.valdez@enron.com | 0.46
#         81 |                 cheryl.johnson@enron.com | 0.64
#         82 |                  sheila.glover@enron.com | 0.30
#         83 |                  dutch.quigley@enron.com | 0.15
#         84 |                    w..cantrell@enron.com | 0.47
#         85 |                   paul.kaufman@enron.com | 0.33
#         86 |               joe.stepenovitch@enron.com | 0.28
#         87 |                     greg.piper@enron.com | 0.26
#         88 |                   shona.wilson@enron.com | 0.26
#         89 |                 heather.dunton@enron.com | 0.34
#         90 |          nancy.sellers@robertmondavi.com | 0.60
#         91 |               michael.tribolet@enron.com | 0.31
#         92 |                 patrice.l.mims@enron.com | 0.18
#         93 |               hunter.s.shively@enron.com | 0.13
#         94 |                    alan.comnes@enron.com | 0.32
#         95 |                     liz.taylor@enron.com | 0.20
#         96 |                     ben.jacoby@enron.com | 0.30
#         97 |                  paul.d.thomas@enron.com | 0.15
#         98 |                 jason.williams@enron.com | 0.23
#         99 |                    amr.ibrahim@enron.com | 0.40
#        100 |                      l..denton@enron.com | 0.57
#        101 |            darrell.schoolcraft@enron.com | 0.25
#        102 |                amy.fitzpatrick@enron.com | 0.36
#        103 |               fletcher.j.sturm@enron.com | 0.04
#        104 |                  lorna.brennan@enron.com | 0.56
#        105 |                  tanya.rohauer@enron.com | 0.29
#        106 |                        vkaminski@aol.com | 0.43
#        107 |             joannie.williamson@enron.com | 0.54
#        108 |                  karen.buckley@enron.com | 0.35
#        109 |                       jbennett@gmssr.com | 0.40
#        110 |               stephanie.miller@enron.com | 0.28
#        111 |                kimberly.hillis@enron.com | 0.21
#        112 |                grace.rodriguez@enron.com | 0.33
#        113 |                lisa.mellencamp@enron.com | 0.21
#        114 |    schwabalerts.marketupdates@schwab.com | 0.50
#        115 |                  brian.redmond@enron.com | 0.30
#        116 |                  john.zufferli@enron.com | 0.09
#        117 |                    david.portz@enron.com | 0.22
#        118 |                  andrew.edison@enron.com | 0.21
#        119 |              kathleen.carnahan@enron.com | 0.43
#        120 |                     david.port@enron.com | 0.25
#        121 |                 keegan.farrell@enron.com | 0.48
#        122 |                     tim.belden@enron.com | 0.22
#        123 |                     mike.maggi@enron.com | 0.41
#        124 |                julie.armstrong@enron.com | 0.32
# ------------------------------
# error TOT = 0.27
#          0 |               hunter.s.shively@enron.com | 0.15
#         64 |                 keegan.farrell@enron.com | 0.46
#         65 |                     matt.smith@enron.com | 0.10
#         66 |                       kim.ward@enron.com | 0.13
#         67 |                 ginger.dernehl@enron.com | 0.53
#         68 |                 cheryl.johnson@enron.com | 0.64
#         69 |                   paul.kaufman@enron.com | 0.35
#         70 |               monika.causholli@enron.com | 0.27
#         71 |                     brad.mckay@enron.com | 0.15
#         72 |                  karen.buckley@enron.com | 0.31
#         73 |                     jane.tholt@enron.com | 0.08
#         74 |                   paul.y barbo@enron.com | 0.17
#         75 |                tori.kuykendall@enron.com | 0.05
#         76 |                harry.kingerski@enron.com | 0.35
#         77 |                   beth.cherry@enform.com | 0.45
#         78 |                  martin.cuilla@enron.com | 0.18
#         79 |                     m..schmidt@enron.com | 0.50
#         80 |               sandra.f.brawner@enron.com | 0.18
#         81 |                 jennifer.thome@enron.com | 0.31
#         82 |                    mark.palmer@enron.com | 0.30
#         83 |                 mark.greenberg@enron.com | 0.30
#         84 |                stephanie.panus@enron.com | 0.37
#         85 |                     liz.taylor@enron.com | 0.25
#         86 |                 justin.rostant@enron.com | 0.53
#         87 |                    c..williams@enron.com | 0.36
#         88 |                    amr.ibrahim@enron.com | 0.39
#         89 |                     bob.shults@enron.com | 0.31
#         90 |                 patrice.l.mims@enron.com | 0.13
#         91 |                  becky.spencer@enron.com | 0.51
#         92 |               marcus.nettelton@enron.com | 0.35
#         93 |                amy.fitzpatrick@enron.com | 0.33
#         94 |               michael.tribolet@enron.com | 0.29
#         95 |                  paul.d.thomas@enron.com | 0.13
#         96 |                lisa.mellencamp@enron.com | 0.20
#         97 |                  tanya.rohauer@enron.com | 0.28
#         98 |                    mike.carson@enron.com | 0.06
#         99 |                  jim.schwieger@enron.com | 0.23
#        100 |                     greg.piper@enron.com | 0.24
#        101 |                 janel.guerrero@enron.com | 0.40
#        102 |                     wsmith@wordsmith.org | 0.50
#        103 |                   shona.wilson@enron.com | 0.29
#        104 |                  suzanne.adams@enron.com | 0.40
#        105 |                     ben.jacoby@enron.com | 0.30
#        106 |                  sheila.glover@enron.com | 0.24
#        107 |             joannie.williamson@enron.com | 0.35
#        108 |               holden.salisbury@enron.com | 0.10
#        109 |               joe.stepenovitch@enron.com | 0.22
#        110 |                  brian.redmond@enron.com | 0.31
#        111 |                            alex@pira.com | 0.50
#        112 |                      l..denton@enron.com | 0.69
#        113 |                     mike.maggi@enron.com | 0.35
#        114 |                    jason.wolfe@enron.com | 0.25
#        115 |                     tim.belden@enron.com | 0.14
#        116 |                christian.yoder@enron.com | 0.30
#        117 |    schwabalerts.marketupdates@schwab.com | 0.50
#        118 |                     l..nicolay@enron.com | 0.35
#        119 |                kimberly.hillis@enron.com | 0.18
#        120 |                  andrew.edison@enron.com | 0.26
#        121 |                      jean.mrha@enron.com | 0.38
#        122 |                   megan.parker@enron.com | 0.49
#        123 |               christina.valdez@enron.com | 0.42
#        124 |                    david.portz@enron.com | 0.29
# ------------------------------
# error TOT = 0.27
