# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = 'data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
import TFIDF_mod
from TFIDF_mod import TFIDF

# transform each mail body into tfidf vector
# /!\ function can take 1-2 min to execute
TFIDF = TFIDF()
X_TFIDF = TFIDF.fit_transform(X_df) # resulting shape : (43613, 275988)

# %%
from sklearn.model_selection import ShuffleSplit
import predictor
from predictor import Predictor_1

# splitting data for cross validation
skf = ShuffleSplit(n_splits=2, test_size=0.2)
print('%10s | %40s | %10s' %('sender_nb', 'sender', 'accuracy'))
print('%10s + %40s + %10s' %(10*'-', 40*'-', 10*'-'))
for train_is, test_is in skf.split(y_df):
    
    X_tfidf_train = X_TFIDF[train_is].copy()
    y_train = y_df.recipients.loc[train_is].copy()
    X_tfidf_test = X_TFIDF[test_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    accuracy = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_1(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books)
        y_pred[sender_test_is] = pdt[sender].predict_1(X_tfidf_test[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is], k=10)
        accuracy_TOT += accuracy[sender]
        print('%.2f' %(accuracy[sender]))

    print('%30s'%(30*'-'))
    print('error TOT = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |   accuracy
# ---------- + ---------------------------------------- + ----------
#          0 |                    jason.wolfe@enron.com | 0.20
#          1 |                sara.shackleton@enron.com | 0.09
#          2 |                       rick.buy@enron.com | 0.10
#          3 |                  tanya.rohauer@enron.com | 0.29
#          4 |                  david.forster@enron.com | 0.27
#          5 |                  michelle.cash@enron.com | 0.11
#          6 |                 ginger.dernehl@enron.com | 0.51
#          7 |                  peter.keohane@enron.com | 0.22
#          8 |                      eric.bass@enron.com | 0.13
#          9 |                  chris.germany@enron.com | 0.06
#         10 |                     sally.beck@enron.com | 0.09
#         11 |                 kevin.m.presto@enron.com | 0.14
#         12 |        enron_update@concureworkplace.com | 0.16
#         13 |                 phillip.m.love@enron.com | 0.06
#         14 |                   holly.keiser@enron.com | 0.42
#         15 |                    c..williams@enron.com | 0.31
#         16 |               hunter.s.shively@enron.com | 0.14
#         17 |                     scott.neal@enron.com | 0.11
#         18 |                   beth.cherry@enform.com | 0.43
#         19 |               larry.f.campbell@enron.com | 0.10
#         20 |                  chris.dorland@enron.com | 0.08
#         21 |                     mark.whitt@enron.com | 0.24
#         22 |                  john.lavorato@enron.com | 0.10
#         23 |                     ben.jacoby@enron.com | 0.34
#         24 |                     liz.taylor@enron.com | 0.27
#         25 |                  james.derrick@enron.com | 0.22
#         26 |                stephanie.panus@enron.com | 0.37
#         27 |                 mark.greenberg@enron.com | 0.29
#         28 |                     lynn.blair@enron.com | 0.19
#         29 |                richard.shapiro@enron.com | 0.28
#         30 |                james.d.steffes@enron.com | 0.17
#         31 |               stephanie.miller@enron.com | 0.32
#         32 |                  becky.spencer@enron.com | 0.61
#         33 |                       kim.ward@enron.com | 0.09
#         34 |                    britt.davis@enron.com | 0.28
#         35 |                       jbennett@gmssr.com | 0.45
#         36 |                   mike.grigsby@enron.com | 0.26
#         37 |                    susan.scott@enron.com | 0.06
#         38 |                  brian.redmond@enron.com | 0.25
#         39 |                     jane.tholt@enron.com | 0.08
#         40 |                         taylor@enron.com | 0.13
#         41 |                     m..schmidt@enron.com | 0.50
#         42 |                  martin.cuilla@enron.com | 0.13
#         43 |                   paul.kaufman@enron.com | 0.33
#         44 |                  john.zufferli@enron.com | 0.07
#         45 |                  lorna.brennan@enron.com | 0.55
#         46 |                 jason.williams@enron.com | 0.21
#         47 |                   megan.parker@enron.com | 0.47
#         48 |               sandra.f.brawner@enron.com | 0.14
#         49 |                   paul.y barbo@enron.com | 0.21
#         50 |                      mary.cook@enron.com | 0.27
#         51 |               joe.stepenovitch@enron.com | 0.27
#         52 |                  dutch.quigley@enron.com | 0.13
#         53 |                       c..giron@enron.com | 0.12
#         54 |               monika.causholli@enron.com | 0.24
#         55 |                    alan.comnes@enron.com | 0.30
#         56 |              kathleen.carnahan@enron.com | 0.37
#         57 |                amy.fitzpatrick@enron.com | 0.40
#         58 |                  andrew.edison@enron.com | 0.27
#         59 |                 barry.tycholiz@enron.com | 0.14
#         60 |               fletcher.j.sturm@enron.com | 0.11
#         61 |                      m..forney@enron.com | 0.14
#         62 |                    mike.carson@enron.com | 0.12
#         63 |                 mark.mcconnell@enron.com | 0.26
#         64 |                 jonathan.mckay@enron.com | 0.14
#         65 |                     david.port@enron.com | 0.26
#         66 |                    marie.heard@enron.com | 0.12
#         67 |            darrell.schoolcraft@enron.com | 0.29
#         68 |                  sheila.glover@enron.com | 0.29
#         69 |                     matt.smith@enron.com | 0.10
#         70 |                     bob.shults@enron.com | 0.29
#         71 |                grace.rodriguez@enron.com | 0.38
#         72 |             kenneth.thibodeaux@enron.com | 0.61
#         73 |                 heather.dunton@enron.com | 0.35
#         74 |                    david.portz@enron.com | 0.26
#         75 |                 jennifer.thome@enron.com | 0.34
#         76 |                  jim.schwieger@enron.com | 0.19
#         77 |                russell.diamond@enron.com | 0.24
#         78 |                     wsmith@wordsmith.org | 0.50
#         79 |                tori.kuykendall@enron.com | 0.07
#         80 |                 stacey.w.white@enron.com | 0.35
#         81 |                 cheryl.johnson@enron.com | 0.66
#         82 |                 stanley.horton@enron.com | 0.09
#         83 |               marcus.nettelton@enron.com | 0.32
#         84 |                julie.armstrong@enron.com | 0.35
#         85 |                  karen.buckley@enron.com | 0.43
#         86 |             joannie.williamson@enron.com | 0.40
#         87 |                    rahil.jafry@enron.com | 0.40
#         88 |                      jean.mrha@enron.com | 0.37
#         89 |                    w..cantrell@enron.com | 0.51
#         90 |                     tim.belden@enron.com | 0.18
#         91 |                   shona.wilson@enron.com | 0.29
#         92 |                      sylvia.hu@enron.com | 0.39
#         93 |                 janel.guerrero@enron.com | 0.39
#         94 |                 justin.rostant@enron.com | 0.51
#         95 |          nancy.sellers@robertmondavi.com | 0.60
#         96 |                    andy.zipper@enron.com | 0.09
#         97 |                    karen.denne@enron.com | 0.37
#         98 |                christian.yoder@enron.com | 0.28
#         99 |                lisa.mellencamp@enron.com | 0.20
#        100 |                      l..denton@enron.com | 0.67
#        101 |                 alan.aronowitz@enron.com | 0.20
#        102 |                     greg.piper@enron.com | 0.19
#        103 |               michael.tribolet@enron.com | 0.37
#        104 |                stephanie.sever@enron.com | 0.27
#        105 |                phillip.platter@enron.com | 0.20
#        106 |                     l..nicolay@enron.com | 0.39
#        107 |                    cindy.stark@enron.com | 0.15
#        108 |                    andrea.ring@enron.com | 0.25
#        109 |               errol.mclaughlin@enron.com | 0.17
#        110 |                    amr.ibrahim@enron.com | 0.49
#        111 |                    mark.palmer@enron.com | 0.32
#        112 |                     mike.maggi@enron.com | 0.40
#        113 |               holden.salisbury@enron.com | 0.10
#        114 |                  suzanne.adams@enron.com | 0.37
#        115 |                  paul.d.thomas@enron.com | 0.17
#        116 |                            alex@pira.com | 0.50
#        117 |    schwabalerts.marketupdates@schwab.com | 0.50
#        118 |                 patrice.l.mims@enron.com | 0.12
#        119 |                        vkaminski@aol.com | 0.43
#        120 |                harry.kingerski@enron.com | 0.31
#        121 |                     brad.mckay@enron.com | 0.20
#        122 |               christina.valdez@enron.com | 0.50
#        123 |                 keegan.farrell@enron.com | 0.43
#        124 |                kimberly.hillis@enron.com | 0.23
# ------------------------------
# error TOT = 0.27
#          0 |                  chris.dorland@enron.com | 0.10
#          1 |                    andrea.ring@enron.com | 0.13
#          2 |                       jbennett@gmssr.com | 0.36
#          3 |                  john.lavorato@enron.com | 0.12
#          4 |                     m..schmidt@enron.com | 0.50
#          5 |                    mark.palmer@enron.com | 0.35
#          6 |                  dutch.quigley@enron.com | 0.19
#          7 |                sara.shackleton@enron.com | 0.09
#          8 |                  paul.d.thomas@enron.com | 0.27
#          9 |                     lynn.blair@enron.com | 0.21
#         10 |                 mark.greenberg@enron.com | 0.25
#         11 |                 heather.dunton@enron.com | 0.27
#         12 |                  chris.germany@enron.com | 0.06
#         13 |                  michelle.cash@enron.com | 0.13
#         14 |                    c..williams@enron.com | 0.35
#         15 |                    amr.ibrahim@enron.com | 0.39
#         16 |                 kevin.m.presto@enron.com | 0.13
#         17 |                    marie.heard@enron.com | 0.11
#         18 |            darrell.schoolcraft@enron.com | 0.29
#         19 |               errol.mclaughlin@enron.com | 0.12
#         20 |                  sheila.glover@enron.com | 0.28
#         21 |                         taylor@enron.com | 0.11
#         22 |                       kim.ward@enron.com | 0.11
#         23 |                  james.derrick@enron.com | 0.23
#         24 |                     bob.shults@enron.com | 0.28
#         25 |                  john.zufferli@enron.com | 0.12
#         26 |        enron_update@concureworkplace.com | 0.12
#         27 |                james.d.steffes@enron.com | 0.15
#         28 |                     liz.taylor@enron.com | 0.22
#         29 |               joe.stepenovitch@enron.com | 0.21
#         30 |               fletcher.j.sturm@enron.com | 0.09
#         31 |                russell.diamond@enron.com | 0.23
#         32 |               marcus.nettelton@enron.com | 0.34
#         33 |                 stanley.horton@enron.com | 0.10
#         34 |             joannie.williamson@enron.com | 0.53
#         35 |                    w..cantrell@enron.com | 0.51
#         36 |                kimberly.hillis@enron.com | 0.30
#         37 |                   mike.grigsby@enron.com | 0.21
#         38 |                 ginger.dernehl@enron.com | 0.49
#         39 |                      eric.bass@enron.com | 0.13
#         40 |                 janel.guerrero@enron.com | 0.42
#         41 |                 barry.tycholiz@enron.com | 0.13
#         42 |                     jane.tholt@enron.com | 0.09
#         43 |    schwabalerts.marketupdates@schwab.com | 0.50
#         44 |                 alan.aronowitz@enron.com | 0.17
#         45 |                  peter.keohane@enron.com | 0.22
#         46 |                 stacey.w.white@enron.com | 0.37
#         47 |                    karen.denne@enron.com | 0.38
#         48 |                 phillip.m.love@enron.com | 0.09
#         49 |                     matt.smith@enron.com | 0.11
#         50 |                     sally.beck@enron.com | 0.08
#         51 |          nancy.sellers@robertmondavi.com | 0.60
#         52 |                    susan.scott@enron.com | 0.06
#         53 |                  jim.schwieger@enron.com | 0.19
#         54 |                     ben.jacoby@enron.com | 0.28
#         55 |                richard.shapiro@enron.com | 0.29
#         56 |                tori.kuykendall@enron.com | 0.04
#         57 |                   paul.kaufman@enron.com | 0.31
#         58 |                    cindy.stark@enron.com | 0.15
#         59 |                stephanie.panus@enron.com | 0.35
#         60 |                       c..giron@enron.com | 0.12
#         61 |                    andy.zipper@enron.com | 0.09
#         62 |                lisa.mellencamp@enron.com | 0.22
#         63 |                      m..forney@enron.com | 0.15
#         64 |                  martin.cuilla@enron.com | 0.11
#         65 |             kenneth.thibodeaux@enron.com | 0.64
#         66 |                     greg.piper@enron.com | 0.23
#         67 |                christian.yoder@enron.com | 0.35
#         68 |                    alan.comnes@enron.com | 0.36
#         69 |                            alex@pira.com | 0.50
#         70 |               holden.salisbury@enron.com | 0.05
#         71 |                stephanie.sever@enron.com | 0.30
#         72 |               larry.f.campbell@enron.com | 0.10
#         73 |               hunter.s.shively@enron.com | 0.17
#         74 |                       rick.buy@enron.com | 0.10
#         75 |                     scott.neal@enron.com | 0.12
#         76 |                   holly.keiser@enron.com | 0.52
#         77 |                  lorna.brennan@enron.com | 0.57
#         78 |                  becky.spencer@enron.com | 0.47
#         79 |                julie.armstrong@enron.com | 0.33
#         80 |                  andrew.edison@enron.com | 0.30
#         81 |                    britt.davis@enron.com | 0.27
#         82 |                   paul.y barbo@enron.com | 0.18
#         83 |                 cheryl.johnson@enron.com | 0.65
#         84 |               monika.causholli@enron.com | 0.22
#         85 |                        vkaminski@aol.com | 0.42
#         86 |                harry.kingerski@enron.com | 0.35
#         87 |                     wsmith@wordsmith.org | 0.50
#         88 |                      mary.cook@enron.com | 0.23
#         89 |                  brian.redmond@enron.com | 0.26
#         90 |                  david.forster@enron.com | 0.32
#         91 |                     mark.whitt@enron.com | 0.23
#         92 |                    mike.carson@enron.com | 0.10
#         93 |                 patrice.l.mims@enron.com | 0.12
#         94 |               michael.tribolet@enron.com | 0.34
#         95 |                 jennifer.thome@enron.com | 0.34
#         96 |                      jean.mrha@enron.com | 0.31
#         97 |                  karen.buckley@enron.com | 0.38
#         98 |                     david.port@enron.com | 0.20
#         99 |               stephanie.miller@enron.com | 0.30
#        100 |                 mark.mcconnell@enron.com | 0.25
#        101 |                    jason.wolfe@enron.com | 0.07
#        102 |                     brad.mckay@enron.com | 0.18
#        103 |                amy.fitzpatrick@enron.com | 0.33
#        104 |                   beth.cherry@enform.com | 0.45
#        105 |                  tanya.rohauer@enron.com | 0.30
#        106 |                 jonathan.mckay@enron.com | 0.12
#        107 |                     l..nicolay@enron.com | 0.43
#        108 |                   megan.parker@enron.com | 0.45
#        109 |                 justin.rostant@enron.com | 0.50
#        110 |                    rahil.jafry@enron.com | 0.28
#        111 |                phillip.platter@enron.com | 0.18
#        112 |                     mike.maggi@enron.com | 0.35
#        113 |                    david.portz@enron.com | 0.18
#        114 |                     tim.belden@enron.com | 0.20
#        115 |              kathleen.carnahan@enron.com | 0.45
#        116 |                 jason.williams@enron.com | 0.14
#        117 |                   shona.wilson@enron.com | 0.29
#        118 |                 keegan.farrell@enron.com | 0.56
#        119 |               sandra.f.brawner@enron.com | 0.16
#        120 |                  suzanne.adams@enron.com | 0.44
#        121 |               christina.valdez@enron.com | 0.45
#        122 |                      sylvia.hu@enron.com | 0.29
#        123 |                      l..denton@enron.com | 0.67
#        124 |                grace.rodriguez@enron.com | 0.30
# ------------------------------
# error TOT = 0.27
