# %% [markdown]
# <h1>Email recipient recommendation</h1>
#
# <i>Thomas Boudou, Guillaume Richard, Antoine Simoulin</i>
#
# <p style="text-align: justify">It was shown that at work, employees frequently forget to include one or more recipient(s) before sending a message. Conversely, it is common that some recipients of a given message were actually not intended to receive the message. To increase productivity and prevent information leakage, the needs for effective <b>email recipient recommendation</b> systems are thus pressing.
#
# In this challenge, you are asked to develop such a system, which, given the content and the date of a message, recommends a list of <b>10 recipients ranked by decreasing order of relevance</b>.</p>

# %%
# Requirements
# %matplotlib inline
import random
import pandas as pd
import numpy as np
# do not display warnings
import warnings
warnings.filterwarnings("ignore")

# Functions files are saved in "src/" directory.
import sys
sys.path.append('src/')
from accuracy_measure import *

# %%
from load_data import *

# load files
# Data are saved in "data/" directory
path_to_data = '../data/'
training, training_info, test, test_info, y_df = load_data(path_to_data)

# create adress book
# /!\ can take 1-2 min
address_books = create_address_books(training, y_df)

# join train and test files
X_df = join_data(training_info, training)
X_sub_df = join_data(test_info, test)

# %%
import TFIDF_mod
from TFIDF_mod import TFIDF

# transform each mail body into tfidf vector
# /!\ function can take 1-2 min to execute
TFIDF = TFIDF()
X_TFIDF = TFIDF.fit_transform(X_df) # resulting shape : (43613, 275988)
# Out:
# performed Tf-Idf in 100 seconds.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def complete_prediction(k, sender, address_books, res_temp, K=10):
    # k the number of recipients to predict
    k_most = [elt[0] for elt in address_books[sender][:K] if elt[0] not in res_temp]
    k_most = k_most[:k]
    if len(k_most) < k: # sender n'a pas assez de contacts
        k_most.extend([0] * (k-len(k_most)))
    return k_most

class Predictor_2():
    def __init__(self, X, y, sender, address_books,N=10):
        self.N = min(N,10)
        self.train = X
        self.predict = y.values
        self.sender = sender
        self.address_books = address_books
        self.X_recpt = {}
        
        # perform centroid Tf-Idf. i.e each 10 most frequent recipients is represented 
        # by an average of all mail he received.
        # exctract 10 most frequents recipients
        self.k_most = [elt[0] for elt in address_books[sender][:10]]
        # perform average Tf-Idf on 10 most frequents recipients
        for recpt in self.k_most: # loop trough 10 most frequents recipients
            self.X_recpt[recpt] = 0
            N = 0
            for i in range(X.shape[0]): # loop trough all mails send by sender
                if recpt in self.predict[i]: # if recipients is in mail
                    self.X_recpt[recpt] += X[i]
                N +=1
            self.X_recpt[recpt] /= N
            

    def predict_2(self, X):
        res = []
        cos = {}
        for i in range(X.shape[0]):
            # cosine similarity with 10 most frequents recpt
            for recpt, value in self.X_recpt.items():
                if isinstance(self.X_recpt[recpt], list): # check that sender has more than 10 recipients
                    cos[recpt] = cosine_similarity(X[i],self.X_recpt[recpt]).argsort()[:,0][0]
                else:
                    cos[recpt] = 1
            if self.N != 0:
                # return the 10 most frequent recipients in order 
                # given by similarity to their centroid Tf-Idf representation
                res_temp = list(dict(sorted(cos.items(), key=operator.itemgetter(1), reverse=True)[:10]))
            else:
                 res_temp = []
            # if less than 10 recipients, complete the prediction with more frequents users
            if len(res_temp) < 10:
                res_temp.extend(complete_prediction(10-len(res_temp),self.sender, self.address_books, res_temp))
            res.append(res_temp)
        return res

# %%
from sklearn.model_selection import ShuffleSplit

# splitting data for cross validation
skf = ShuffleSplit(n_splits=1, test_size=0.2)
print('%10s | %40s | %13s | %13s' %('sender_nb', 'sender', 'accuracy KNN','accuracy freq'))
print('%10s + %40s + %13s + %13s' %(10*'-', 40*'-', 13*'-', 13*'-'))

for train_is, test_is in skf.split(y_df):
    
    X_tfidf_train = X_TFIDF[train_is].copy()
    y_train = y_df.recipients.loc[train_is].copy()
    X_tfidf_test = X_TFIDF[test_is].copy()
    y_test = y_df.recipients.loc[test_is].copy()
    X_test_df = X_df.loc[test_is].copy()
    X_train_df = X_df.loc[train_is].copy()
    
    i=0
    pdt = {}
    pdt_freq = {}
    accuracy = {}
    accuracy_freq = {}
    accuracy_TOT = 0
    sender_test = X_test_df.sender.unique().tolist()
    y_pred = np.empty((X_test_df.shape[0],10),dtype=object)
    y_pred_freq = np.empty((X_test_df.shape[0],10),dtype=object)

    for sender in sender_test:
        print('%10s | %40s | ' %(sender_test.index(sender), sender), end='')
        # indices corresponding to the sender
        sender_train_is = np.array(X_train_df.sender == sender)
        sender_test_is = np.array(X_test_df.sender == sender)
        
        pdt[sender] = Predictor_2(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books)
        pdt_freq[sender] = Predictor_2(X_tfidf_train[sender_train_is], y_train[sender_train_is], sender, address_books, N=0)
        y_pred[sender_test_is] = pdt[sender].predict_2(X_tfidf_test[sender_test_is])
        y_pred_freq[sender_test_is] = pdt_freq[sender].predict_2(X_tfidf_test[sender_test_is])
        
        accuracy[sender] = mapk(y_test[sender_test_is], y_pred[sender_test_is])
        accuracy_freq[sender] = mapk(y_test[sender_test_is], y_pred_freq[sender_test_is])
        
        accuracy_TOT += accuracy[sender]
        print('%13s | %13s' %(round(accuracy[sender],2),round(accuracy_freq[sender],2)))

    print('%30s'%(90*'-'))
    print('mean accuracy = %.2f' %(accuracy_TOT/len(accuracy)))
# Out:
#  sender_nb |                                   sender |  accuracy KNN | accuracy freq
# ---------- + ---------------------------------------- + ------------- + -------------
#          0 |                sara.shackleton@enron.com |          0.11 |          0.15
#          1 |                  james.derrick@enron.com |          0.14 |          0.39
#          2 |                 phillip.m.love@enron.com |          0.05 |          0.11
#          3 |                lisa.mellencamp@enron.com |          0.19 |          0.42
#          4 |                 kevin.m.presto@enron.com |          0.16 |          0.21
#          5 |                     scott.neal@enron.com |          0.08 |          0.13
#          6 |                     sally.beck@enron.com |          0.09 |          0.18
#          7 |                      m..forney@enron.com |           0.2 |          0.21
#          8 |                     l..nicolay@enron.com |          0.42 |          0.47
#          9 |               marcus.nettelton@enron.com |          0.21 |           0.6
#         10 |                 alan.aronowitz@enron.com |          0.19 |          0.36
#         11 |                    susan.scott@enron.com |           0.1 |          0.09
#         12 |                  dutch.quigley@enron.com |          0.12 |          0.25
#         13 |               hunter.s.shively@enron.com |          0.18 |          0.25
#         14 |                     lynn.blair@enron.com |          0.19 |          0.27
#         15 |                 mark.mcconnell@enron.com |           0.2 |          0.53
#         16 |               monika.causholli@enron.com |          0.26 |          0.29
#         17 |                   mike.grigsby@enron.com |          0.28 |          0.28
#         18 |                  michelle.cash@enron.com |          0.08 |          0.24
#         19 |                     wsmith@wordsmith.org |           1.0 |           1.0
#         20 |                 stacey.w.white@enron.com |          0.17 |          0.66
#         21 |                richard.shapiro@enron.com |           0.2 |          0.48
#         22 |                  chris.germany@enron.com |          0.07 |           0.1
#         23 |                    c..williams@enron.com |          0.41 |          0.44
#         24 |              kathleen.carnahan@enron.com |           0.9 |          0.94
#         25 |                       c..giron@enron.com |           0.1 |          0.19
#         26 |                     brad.mckay@enron.com |          0.24 |           0.3
#         27 |                james.d.steffes@enron.com |          0.17 |          0.25
#         28 |                  chris.dorland@enron.com |          0.12 |          0.17
#         29 |                    andy.zipper@enron.com |          0.14 |          0.17
#         30 |                      eric.bass@enron.com |          0.18 |           0.2
#         31 |                  john.lavorato@enron.com |          0.11 |          0.16
#         32 |                       rick.buy@enron.com |          0.16 |          0.21
#         33 |          nancy.sellers@robertmondavi.com |          0.67 |          0.89
#         34 |                      sylvia.hu@enron.com |          0.27 |          0.31
#         35 |                     greg.piper@enron.com |           0.3 |           0.3
#         36 |               larry.f.campbell@enron.com |          0.15 |          0.16
#         37 |                     mark.whitt@enron.com |          0.16 |          0.37
#         38 |                 cheryl.johnson@enron.com |           0.9 |          0.92
#         39 |               holden.salisbury@enron.com |          0.16 |          0.14
#         40 |                 heather.dunton@enron.com |          0.18 |          0.68
#         41 |                    marie.heard@enron.com |          0.14 |           0.2
#         42 |                  peter.keohane@enron.com |          0.29 |          0.38
#         43 |                   paul.kaufman@enron.com |           0.3 |          0.56
#         44 |                 patrice.l.mims@enron.com |          0.16 |          0.23
#         45 |                 janel.guerrero@enron.com |          0.61 |          0.65
#         46 |                  martin.cuilla@enron.com |          0.14 |          0.17
#         47 |               joe.stepenovitch@enron.com |          0.28 |          0.41
#         48 |                    cindy.stark@enron.com |          0.15 |          0.18
#         49 |                     bob.shults@enron.com |          0.45 |          0.47
#         50 |                     jane.tholt@enron.com |          0.11 |          0.15
#         51 |                 ginger.dernehl@enron.com |          0.71 |          0.78
#         52 |                 stanley.horton@enron.com |          0.09 |          0.21
#         53 |                    andrea.ring@enron.com |          0.33 |          0.38
#         54 |        enron_update@concureworkplace.com |          0.16 |           0.2
#         55 |                      l..denton@enron.com |          0.96 |          0.96
#         56 |                     liz.taylor@enron.com |          0.18 |          0.47
#         57 |               stephanie.miller@enron.com |          0.18 |          0.51
#         58 |                   paul.y barbo@enron.com |          0.14 |          0.29
#         59 |                  lorna.brennan@enron.com |          0.73 |           0.8
#         60 |                    mark.palmer@enron.com |          0.34 |          0.52
#         61 |                      mary.cook@enron.com |          0.22 |          0.36
#         62 |             kenneth.thibodeaux@enron.com |          0.77 |           0.8
#         63 |                       kim.ward@enron.com |          0.12 |          0.18
#         64 |                    david.portz@enron.com |          0.17 |          0.31
#         65 |                    alan.comnes@enron.com |          0.39 |          0.51
#         66 |                stephanie.sever@enron.com |          0.31 |           0.6
#         67 |                  suzanne.adams@enron.com |          0.78 |          0.81
#         68 |                  tanya.rohauer@enron.com |          0.17 |          0.44
#         69 |                 keegan.farrell@enron.com |          0.69 |          0.73
#         70 |               sandra.f.brawner@enron.com |          0.18 |          0.31
#         71 |                    mike.carson@enron.com |          0.12 |          0.16
#         72 |            darrell.schoolcraft@enron.com |          0.22 |          0.47
#         73 |               errol.mclaughlin@enron.com |          0.22 |          0.21
#         74 |                         taylor@enron.com |           0.2 |          0.19
#         75 |                       jbennett@gmssr.com |          0.51 |          0.64
#         76 |                  david.forster@enron.com |          0.24 |          0.46
#         77 |                stephanie.panus@enron.com |          0.49 |           0.5
#         78 |                 jason.williams@enron.com |          0.12 |          0.29
#         79 |                julie.armstrong@enron.com |          0.26 |           0.6
#         80 |                        vkaminski@aol.com |          0.18 |          0.88
#         81 |                christian.yoder@enron.com |          0.26 |          0.57
#         82 |                     matt.smith@enron.com |          0.08 |           0.1
#         83 |                harry.kingerski@enron.com |          0.27 |          0.52
#         84 |                   holly.keiser@enron.com |           0.6 |          0.66
#         85 |                     mike.maggi@enron.com |          0.34 |          0.64
#         86 |                    britt.davis@enron.com |          0.19 |          0.35
#         87 |                    karen.denne@enron.com |          0.44 |          0.61
#         88 |                  karen.buckley@enron.com |          0.47 |          0.51
#         89 |                 justin.rostant@enron.com |          0.59 |          0.66
#         90 |                    rahil.jafry@enron.com |          0.15 |          0.64
#         91 |                  jim.schwieger@enron.com |          0.25 |           0.3
#         92 |                   beth.cherry@enform.com |          0.42 |          0.86
#         93 |                  john.zufferli@enron.com |          0.09 |          0.25
#         94 |                  paul.d.thomas@enron.com |          0.08 |          0.19
#         95 |                     tim.belden@enron.com |          0.21 |          0.26
#         96 |                     ben.jacoby@enron.com |          0.46 |          0.55
#         97 |                grace.rodriguez@enron.com |          0.27 |          0.56
#         98 |                    w..cantrell@enron.com |          0.72 |          0.74
#         99 |             joannie.williamson@enron.com |          0.45 |          0.47
#        100 |                   megan.parker@enron.com |          0.21 |           0.8
#        101 |                     m..schmidt@enron.com |          0.18 |          0.98
#        102 |                tori.kuykendall@enron.com |          0.09 |          0.08
#        103 |                 jonathan.mckay@enron.com |          0.21 |          0.19
#        104 |               michael.tribolet@enron.com |          0.34 |          0.54
#        105 |                  brian.redmond@enron.com |          0.32 |          0.57
#        106 |                 jennifer.thome@enron.com |          0.29 |          0.66
#        107 |                 mark.greenberg@enron.com |          0.26 |          0.49
#        108 |               fletcher.j.sturm@enron.com |           0.1 |          0.13
#        109 |                amy.fitzpatrick@enron.com |          0.12 |          0.72
#        110 |                  sheila.glover@enron.com |          0.17 |          0.48
#        111 |                kimberly.hillis@enron.com |           0.2 |          0.55
#        112 |                  becky.spencer@enron.com |          0.63 |          0.66
#        113 |                russell.diamond@enron.com |           0.3 |          0.35
#        114 |                 barry.tycholiz@enron.com |          0.22 |          0.22
#        115 |                      jean.mrha@enron.com |          0.23 |          0.58
#        116 |                  andrew.edison@enron.com |          0.27 |          0.45
#        117 |                   shona.wilson@enron.com |          0.32 |          0.45
#        118 |    schwabalerts.marketupdates@schwab.com |           1.0 |           1.0
#        119 |                     david.port@enron.com |          0.16 |          0.35
#        120 |                    amr.ibrahim@enron.com |          0.38 |          0.63
#        121 |               christina.valdez@enron.com |          0.41 |          0.81
#        122 |                    jason.wolfe@enron.com |          0.15 |          0.33
#        123 |                phillip.platter@enron.com |           0.2 |          0.13
#        124 |                            alex@pira.com |           1.0 |           1.0
# ------------------------------------------------------------------------------------------
# error TOT = 0.30

# %%
print(y_pred[np.array(X_test_df.sender == 'mark.mcconnell@enron.com')])
# Out:
# [['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']
#  ['kimberly.watson@enron.com' 'michael.ratner@enron.com'
#   'dennis.alters@enron.com' 'james.centilli@enron.com'
#   'steven.harris@enron.com' 'no.address@enron.com' 'lee.huber@enron.com'
#   'sarah.mcconnell@compaq.com' 'rod.hayslett@enron.com'
#   'mansoor.abdmoulaie@enron.com']]

# %%
print(y_test[np.array(X_test_df.sender == 'mark.mcconnell@enron.com')].values)
# Out:
# [ ['bill.windle@enron.com', 'sean.bolks@enron.com', 'kimberly.watson@enron.com']
#  ['rbjohnson@cmsenergy.com'] ['no.address@enron.com']
#  ['no.address@enron.com'] ['no.address@enron.com'] ['no.address@enron.com']
#  ['eleydic@yahoo.com'] ['michael.ratner@enron.com']
#  ['no.address@enron.com']
#  ['james.centilli@enron.com', 'kimberly.watson@enron.com']
#  ['lorna.brennan@enron.com', 'paul.y', 'barbo@enron.com']
#  ['no.address@enron.com'] ['zachary.mccarroll@enron.com']
#  ['no.address@enron.com'] ['kimberly.watson@enron.com']
#  ['carolyn.graham@enron.com'] ['dennis.alters@enron.com']
#  ['sarah.mcconnell@compaq.com', 'mcconnell@enron.com']
#  ['jim.curry@enron.com', 'larry.gleffe@enron.com', 'kimberly.watson@enron.com', 'ld.stephens@enron.com', 'larry.f.campbell@enron.com', 'mike.ames@enron.com']
#  ['ckdk@hotmail.com'] ['no.address@enron.com'] ['no.address@enron.com']
#  ['no.address@enron.com'] ['gabriel.chavez@enron.com']
#  ['no.address@enron.com'] ['paul.y', 'barbo@enron.com']
#  ['no.address@enron.com'] ['no.address@enron.com'] ['no.address@enron.com']
#  ['james.centilli@enron.com', 'mansoor.abdmoulaie@enron.com', 'kimberly.watson@enron.com', 'lee.huber@enron.com', 'steven.harris@enron.com', 'tracy.geaccone@enron.com', 'robert.kilmer@enron.com', 'eric.gadd@enron.com', 'rod.hayslett@enron.com', 'teb.lokey@enron.com']
#  ['no.address@enron.com'] ['no.address@enron.com'] ['no.address@enron.com']
#  ['cassiezh@ou.edu'] ['kimberly.watson@enron.com']
#  ['audrey.robertson@enron.com'] ['michelle.lokay@enron.com']
#  ['mark.mcconnell@enron.com', 'eric.faucheaux@enron.com', 'james.centilli@enron.com', 'kimberly.watson@enron.com', 'dennis.alters@enron.com', 'morgan.gottsponer@enron.com']
#  ['no.address@enron.com'] ['sarah.mcconnell@compaq.com']
#  ['james.centilli@enron.com', 'mansoor.abdmoulaie@enron.com', 'kimberly.watson@enron.com', 'lee.huber@enron.com', 'steven.harris@enron.com', 'tracy.geaccone@enron.com', 'robert.kilmer@enron.com', 'eric.gadd@enron.com', 'rod.hayslett@enron.com', 'teb.lokey@enron.com']
#  ['no.address@enron.com']]
